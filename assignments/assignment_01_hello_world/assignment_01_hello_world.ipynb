# %% [markdown]
# # Assignment 01 — Hello World
# **CPS 141 | Dylan Kur | Washtenaw Community College**
#
# ---
#
# > *Every expert was once a beginner. Every pro was once an amateur.
# > Every master was once a disaster. — Robin Sharma*
#
# ---

# %% [markdown]
# ## Setup
# Run this cell first every time. It loads your environment variables and imports the tools you need.

# %%
# --- Load environment variables from .env ---
from dotenv import load_dotenv
import os

load_dotenv('../../../.env')  # reach up to the root .env file

# --- Standard imports ---
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

print('✅ Setup complete. Ready to code!')
# Out:
# ✅ Setup complete. Ready to code!

# %% [markdown]
# ---
# ## Part 1 — Your First Python Program
#
# Every programmer's first program does the same thing: print `Hello, World!`
# It's a tradition. Welcome to the club.

# %%
# Your first line of Python
# The print() function outputs text to the screen
print('Hello, World!')
# Out:
# Hello, World!

# %% [markdown]
# ---
# ## Part 2 — Assignment Work
#
# <!-- Replace this with the actual assignment description -->

# %%
# Your code here

# %% [markdown]
# ---
# ## Part 3 — Output
#
# Any files you create should be saved to the `output/` folder.
# Any charts you generate should be saved to the `assets/` folder.

# %%
# Example: saving a file to output/
# df.to_csv('output/results.csv', index=False)

# Example: saving a chart to assets/
# plt.savefig('assets/chart.png', dpi=150, bbox_inches='tight')

# %% [markdown]
# ---
# ## Reflection
#
# Answer these questions in the cell below (as a comment or a print statement):
# 1. What did you learn from this assignment?
# 2. What was the hardest part?
# 3. What question do you still have?

# %%
# 1. What I learned:

# 2. Hardest part:

# 3. My question:

# %% [markdown]
# ---
# *CPS 141 | Dylan Kur | 💛💙 Go Blue!*
